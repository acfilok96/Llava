# %%
# %pip install -q llama-index-vector-stores-qdrant
# %pip install -q llama-index-readers-file
# %pip install -q llama-index-multi-modal-llms-replicate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 631.0/631.0 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 206.3/206.3 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.7/226.7 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.6/294.6 kB 22.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.0/77.0 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
# ...

# %%
# %pip install -q unstructured replicate
# %pip install -q llama_index ftfy regex tqdm
# %pip install -q git+https://github.com/openai/CLIP.git
# %pip install -q torch torchvision
# %pip install -q matplotlib scikit-image
# %pip install -q -U qdrant_client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 421.5/421.5 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 17.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 24.8 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993225 sha256=6af5ca220a7de44507dd084a9b1122bb40903a02cc994ea97c9b5fe9a5eaf84e
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 29.4 MB/s eta 0:00:00
# ...

# %%
import os

REPLICATE_API_TOKEN = "r8_QI4fKqpZOUzEyk848wnUq6mBzI8ihHp3tREdW"  # Your Relicate API token here
os.environ["REPLICATE_API_TOKEN"] = REPLICATE_API_TOKEN

# %%
from llama_index.multi_modal_llms.replicate import ReplicateMultiModal
from llama_index.core.schema import ImageDocument
from llama_index.multi_modal_llms.replicate.base import (
    REPLICATE_MULTI_MODAL_LLM_MODELS,
)

imageUrl = "/content/vegetables.jpg"
# print(imageUrl)

llava_multi_modal_llm = ReplicateMultiModal(
    model=REPLICATE_MULTI_MODAL_LLM_MODELS["llava-13b"],
    max_new_tokens=200,
    temperature=0.1,
)

prompt = "Describe the image."

llava_response = llava_multi_modal_llm.complete(
    prompt=prompt,
    image_documents=[ImageDocument(image_path=imageUrl)],
)
# Out:
# /content/vegetables.jpg

# %%
print(llava_response.text)
# Out:
# The image features a wooden table filled with a variety of fresh vegetables. There are several carrots spread across the table, with some placed closer to the front and others towards the back. A bunch of broccoli is also present, occupying a significant portion of the table.
#
# In addition to the carrots and broccoli, there are other vegetables such as a cucumber, a tomato, and a cauliflower. The table is well-stocked with these fresh vegetables, making it an appealing display for a healthy meal.

# %%
from IPython.display import display, Markdown, Latex, HTML, JSON
Markdown(llava_response.text)
# Out:
# The image features a wooden table filled with a variety of fresh vegetables. There are several carrots spread across the table, with some placed closer to the front and others towards the back. A bunch of broccoli is also present, occupying a significant portion of the table.
#
# In addition to the carrots and broccoli, there are other vegetables such as a cucumber, a tomato, and a cauliflower. The table is well-stocked with these fresh vegetables, making it an appealing display for a healthy meal.

# %%
from PIL import Image
import matplotlib.pyplot as plt

image = Image.open(imageUrl).convert("RGB")

plt.figure(figsize=(6, 4))
plt.imshow(image)
plt.axis("off")
plt.show()

# %%
Markdown(llava_response.text)
# Out:
# The image features a wooden table filled with a variety of fresh vegetables. There are several carrots spread across the table, with some placed closer to the front and others towards the back. A bunch of broccoli is also present, occupying a significant portion of the table.
#
# In addition to the carrots and broccoli, there are other vegetables such as a cucumber, a tomato, and a cauliflower. The table is well-stocked with these fresh vegetables, making it an appealing display for a healthy meal.
